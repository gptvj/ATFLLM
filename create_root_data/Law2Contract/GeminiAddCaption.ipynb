# %% [markdown]
# ## Init

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/MyDrive/0_JOB/Chunking/")

# %%
# !pip install -q -U google-generativeai

# %%
import pathlib
import textwrap
import time

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


GOOGLE_API_KEY = 'AIzaSyDykAbw-mlBUCnxh6B7JzoFzBw6gdmEuZw'  # nguyen tran

genai.configure(api_key=GOOGLE_API_KEY)
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
model = genai.GenerativeModel('gemini-1.5-flash-latest')
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# ## History

# %% [markdown]
# ### Init

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# model = genai.GenerativeModel('gemini-pro')
chat = model.start_chat(history=[])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-1.5-flash-latest',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )

# %%
# # dịch: cho tôi nội dung một bản hợp đồng
# prompt = """
# 第１章　総則
# 第１条　目的
# 第２条　適用範囲
# 第３条　規則の遵守
# 第４条　改廃

# 第２章　人事
# 第１節　採用
# 第５条　採用
# 第６条　労働条件の明示
# 第７条　採用時の提出書類
# 第８条　試用期間

# 第２節　人事異動等
# 第３章　服務規律
# 第１節　社員の服務
# 第９条　服務
# 第１０条　遵守事項
# 第１１条　ハラスメントの防止
# 第１２条　個人情報等の保護管理
# 第１３条　出退勤
# 第１４条　遅刻、早退、欠勤等

# 第２節　副業・兼業
# 第１５条　副業・兼業

# 第４章　勤務等
# 第１節　労働時間及び休日等
# 第１６条　労働時間及び休憩
# 第１７条　休日
# 第１８条　時間外及び休日労働等
# 第１９条　休日の振替等

# 第５章　休暇等
# 第１節　年次有給休暇
# 第２０条　年次有給休暇の付与
# 第２１条　年次有給休暇の取得
# 第２２条　年次有給休暇の時季指定

# 第２節　出産・育児・介護等に係る休業・休暇等
# 第２３条　産前産後休業
# 第２４条　母性健康管理のための休暇等
# 第２５条　生理日の就業が著しく困難な女性社員に対する措置
# 第２６条　育児時間
# 第２７条　育児・介護休業、子の看護休暇等

# 第３節　臨時の休業
# 第２８条　臨時の休業

# 第６章　賃金
# 第２９条　賃金

# 第７章　解雇
# 第３０条　解雇
# 第３１条　解雇予告
# 第３２条　解雇制限

# 第８章　定年及び退職
# 第３３条　定年
# 第３４条　退職

# 第９章　安全衛生及び災害補償
# 第１節　安全衛生等
# 第３５条　安全衛生
# 第３６条　健康診断
# 第３７条　疾病等による就業禁止
# 第３８条　長時間労働者に対する医師による面接指導の実施
# 第３９条　健康管理上の個人情報の取扱い

# 第２節　災害補償
# 第４０条　業務上災害の補償
# 第４１条　打切補償
# 第４２条　災害補償法令との関係
# 第４３条　労災保険法等の手続

# 第１０章　教育訓練
# 第４４条　教育訓練

# 第１１章　表彰及び制裁
# 第４５条　表彰
# 第４６条　懲戒の種類
# 第４７条　懲戒事由
# 第４８条　損害賠償

# 第１２章　公益通報者の保護
# 第４９条　公益通報者の保護

# 以上が就業規則の「目次」です。
# 次の文が上のリストのどの章または項目に属するかを教えてください。
# 「雇用主は、本契約に基づき従業員に支払うべき賃金を、法定の期日までに、かつ、全額支払うものとする。」

# 出力は次のようになります。
# ユニット：
# もの：
# 説明する：
# """

# %%
# response = chat.send_message(prompt)
# to_markdown(response.text)

# %%
# print(response.text)

# %% [markdown]
# ### Kiểm tra các luật

# %%
import json

# Đọc nội dung từ file JSON
with open('./Data/LawContractAPI_2806.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# In ra các mục của danh sách
for item in data[:5]:
    print(item)
# Out:
# {'question': '雇用主は、本契約に基づき従業員に支払うべき賃金を、法定の期日までに、かつ、全額支払うものとする。', 'relevant_articles': [{'law_id': '賃金の支払の確保等に関する法律/第一章\u3000総則', 'article_id': '1'}]}
# {'question': '雇用主は、従業員が事業を退職する場合、遅滞なく未払い賃金を支払うものとする。', 'relevant_articles': [{'law_id': '賃金の支払の確保等に関する法律/第一章\u3000総則', 'article_id': '1'}]}
# {'question': '雇用主は、従業員が退職する際に、従業員が貯蓄金の保全措置について適切な情報を得られるよう努めるものとする。', 'relevant_articles': [{'law_id': '賃金の支払の確保等に関する法律/第一章\u3000総則', 'article_id': '1'}]}
# {'question': '景気の変動、産業構造の変化その他の事情により企業経営が安定を欠くに至った場合、雇用主は、従業員の賃金の支払を確保するための適切な措置を講じるものとする。', 'relevant_articles': [{'law_id': '賃金の支払の確保等に関する法律/第一章\u3000総則', 'article_id': '1'}]}
# {'question': '事業活動に著しい支障が生じたことにより賃金の支払を受けることが困難となった従業員に対し、雇用主は必要な保護措置を講じるものとする。', 'relevant_articles': [{'law_id': '賃金の支払の確保等に関する法律/第一章\u3000総則', 'article_id': '1'}]}

# %%
# total_data = []

# %% [markdown]
# ### Some article_id cùng một lúc

# %%
len(total_data)
# Out:
# 894

# %%
a = len(total_data)
b = len(data)
count_request = 1
new_data = []
for i, item in enumerate(data[a:b]):
  # print(i, item)

  prompt = f"""
第１章　総則
第１条　目的
第２条　適用範囲
第３条　規則の遵守
第４条　改廃

第２章　人事
第１節　採用
第５条　採用x
第６条　労働条件の明示
第７条　採用時の提出書類
第８条　試用期間

第２節　人事異動等
第３章　服務規律
第１節　社員の服務
第９条　服務
第１０条　遵守事項
第１１条　ハラスメントの防止
第１２条　個人情報等の保護管理
第１３条　出退勤
第１４条　遅刻、早退、欠勤等

第２節　副業・兼業
第１５条　副業・兼業

第４章　勤務等
第１節　労働時間及び休日等
第１６条　労働時間及び休憩
第１７条　休日
第１８条　時間外及び休日労働等
第１９条　休日の振替等

第５章　休暇等
第１節　年次有給休暇
第２０条　年次有給休暇の付与
第２１条　年次有給休暇の取得
第２２条　年次有給休暇の時季指定

第２節　出産・育児・介護等に係る休業・休暇等
第２３条　産前産後休業
第２４条　母性健康管理のための休暇等
第２５条　生理日の就業が著しく困難な女性社員に対する措置
第２６条　育児時間
第２７条　育児・介護休業、子の看護休暇等

第３節　臨時の休業
第２８条　臨時の休業

第６章　賃金
第２９条　賃金

第７章　解雇
第３０条　解雇
第３１条　解雇予告
第３２条　解雇制限

第８章　定年及び退職
第３３条　定年
第３４条　退職

第９章　安全衛生及び災害補償
第１節　安全衛生等
第３５条　安全衛生
第３６条　健康診断
第３７条　疾病等による就業禁止
第３８条　長時間労働者に対する医師による面接指導の実施
第３９条　健康管理上の個人情報の取扱い

第２節　災害補償
第４０条　業務上災害の補償
第４１条　打切補償
第４２条　災害補償法令との関係
第４３条　労災保険法等の手続

第１０章　教育訓練
第４４条　教育訓練

第１１章　表彰及び制裁
第４５条　表彰
第４６条　懲戒の種類
第４７条　懲戒事由
第４８条　損害賠償

第１２章　公益通報者の保護
第４９条　公益通報者の保護

こちらは労働規則の「目次」です。
上記リストの中で次の文がどの章または節に属しているか教えてください。それがその章に属していない場合、結果は「False」を返します。
「{item['question']}」

出力は次のようになります。
ユニット：第６章　賃金
もの：第２９条　賃金
説明する：
"""
  count = 0
  is_save = True
  while True:
    count += 1
    if count > 3:
      is_save = False
      break
    # try:
    # chat.history = chat.history[:-6]
    count_request += 1
    if count_request > 6:
      time.sleep(60)
      count_request = 1
    response = chat.send_message(prompt)
    # except:
    #   print("error")
    #   continue
    break
  print("content", a+i, "\n", response.text)
  if "False" in response.text:
    muc = ""
    dieu = ""
  elif "ユニット：" in response.text and "もの：" in response.text:
    # print("this")
    muc = response.text.split("ユニット：")[1].split("もの：")[0]
    dieu = response.text.split("もの：")[1].split("説明する：")[0]
  elif "ユニット:" in response.text and "もの:" in response.text:
    # print("this")
    muc = response.text.split("ユニット:")[1].split("もの:")[0]
    dieu = response.text.split("もの:")[1].split("説明する:")[0]
  else:
    print("no find muc, dieu")
    muc = ""
    dieu = ""

  if is_save:
    new_item = {
        "muc": muc,
        "dieu": dieu,
        "question": item['question'],
        "relevant_articles": item['relevant_articles']
    }
    print(new_item)
    new_data.append(new_item)
    # print(len(new_data))
# Out:
# content 894
#  出力：
# ユニット：第２章　人事
# 節：第２節　人事異動等
# 説明：この文は、従業員が育児・介護休業等の休業を取得する際の必要な措置を会社が講じることを示しており、人事異動等の範囲に含まれます。
#
# no find muc, dieu
# {'muc': '', 'dieu': '', 'question': '会社は、従業員が育児・介護休業等の休業を取得する際の必要な措置を講じ、従業員の休業取得の円滑化に努めます。', 'relevant_articles': [{'law_id': '育児休業、介護休業等育児又は家族介護を行う労働者の福祉に関する法律/第十三章\u3000罰則', 'article_id': '4'}]}
# content 895
#  出力:
# ユニット: 第５章　休暇等
# 節: 第２節　出産・育児・介護等に係る休業・休暇等
# 説明する: この文は、従業員が育児休業または介護休業を取得する場合の必要な書類提出について規定しており、第５章の第２節「出産・育児・介護等に係る休業・休暇等」に属します。
#
# no find muc, dieu
# {'muc': '', 'dieu': '', 'question': '従業員は、育児休業または介護休業を取得する場合、育児休業、介護休業等育児又は家族介護を行う労働者の福祉に関する法律第56条の規定に従い、会社に対して必要な書類を提出するものとする。', 'relevant_articles': [{'law_id': '育児休業、介護休業等育児又は家族介護を行う労働者の福祉に関する法律/第十三章\u3000罰則', 'article_id': '5'}]}
# content 896
#  出力:
# ユニット: 第５章　休暇等
# 節: 第２節　出産・育児・介護等に係る休業・休暇等
# 説明する: この文は、従業員が育児休業または介護休業取得の申告に関して虚偽の報告を行わないことを定めており、第５章の第２節「出産・育児・介護等に係る休業・休暇等」に属します。
#
# no find muc, dieu
# ...

# %%
total_data.extend(new_data)

# %%
for item in total_data:
  print(item)
# Out:
# {'muc': '第６章\u3000賃金\n', 'dieu': '第２９条\u3000賃金\n', 'question': '雇用主は、本契約に基づき従業員に支払うべき賃金を、法定の期日までに、かつ、全額支払うものとする。', 'relevant_articles': [{'law_id': '賃金の支払の確保等に関する法律/第一章\u3000総則', 'article_id': '1'}]}
# {'muc': '第６章\u3000賃金\n', 'dieu': '第２９条\u3000賃金\n', 'question': '雇用主は、従業員が事業を退職する場合、遅滞なく未払い賃金を支払うものとする。', 'relevant_articles': [{'law_id': '賃金の支払の確保等に関する法律/第一章\u3000総則', 'article_id': '1'}]}
# {'muc': '', 'dieu': '', 'question': '雇用主は、従業員が退職する際に、従業員が貯蓄金の保全措置について適切な情報を得られるよう努めるものとする。', 'relevant_articles': [{'law_id': '賃金の支払の確保等に関する法律/第一章\u3000総則', 'article_id': '1'}]}
# {'muc': '第６章\u3000賃金\n', 'dieu': '第２９条\u3000賃金\n', 'question': '景気の変動、産業構造の変化その他の事情により企業経営が安定を欠くに至った場合、雇用主は、従業員の賃金の支払を確保するための適切な措置を講じるものとする。', 'relevant_articles': [{'law_id': '賃金の支払の確保等に関する法律/第一章\u3000総則', 'article_id': '1'}]}
# ...

# %%
len(total_data)
# Out:
# 1015

# %%
total_data = total_data[:1000]

# %%
# lưu vào file Data.json
import json

with open('./Data/LawContractAPI_Update_0907.json', 'w', encoding='utf-8') as file:
    json.dump(total_data, file, ensure_ascii=False, indent=4)
    print("Done")
# Out:
# Done

# %%
# import json

# with open('./Data/LawContractAPI_Update_0907.json', 'r', encoding='utf-8') as file:
#     total_data = json.load(file)
#     print(len(total_data))
# Out:
# 894
